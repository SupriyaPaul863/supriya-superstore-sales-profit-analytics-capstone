# %%
import pandas as pd

# Unscaled datasets (Decision Tree & Random Forest)
X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")
y_train = pd.read_csv("../data/processed/y_train.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test.csv").squeeze()

# Scaled datasets (Linear Regression)
X_train_lr = pd.read_csv("../data/processed/X_train_lr.csv")
X_test_lr = pd.read_csv("../data/processed/X_test_lr.csv")
y_train_lr = pd.read_csv("../data/processed/y_train_lr.csv").squeeze()
y_test_lr = pd.read_csv("../data/processed/y_test_lr.csv").squeeze()
